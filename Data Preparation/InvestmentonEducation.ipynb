# %%
import pandas as pd

df = pd.read_csv('Investment on education data.csv', skiprows=4)
df.head()
# Out:
#   Country Name Country Code  \
# 0        Aruba          ABW
# 1  Afghanistan          AFG
# 2       Angola          AGO
# 3      Albania          ALB
# 4      Andorra          AND
#
#                                       Indicator Name     Indicator Code  1960  \
# 0  Government expenditure on education, total (% ...  SE.XPD.TOTL.GD.ZS   NaN
# 1  Government expenditure on education, total (% ...  SE.XPD.TOTL.GD.ZS   NaN
# 2  Government expenditure on education, total (% ...  SE.XPD.TOTL.GD.ZS   NaN
# 3  Government expenditure on education, total (% ...  SE.XPD.TOTL.GD.ZS   NaN
# 4  Government expenditure on education, total (% ...  SE.XPD.TOTL.GD.ZS   NaN
#
#    1961  1962  1963  1964  1965  ...     2012     2013     2014     2015  \
# 0   NaN   NaN   NaN   NaN   NaN  ...  6.54906  6.50538  5.90521  5.97571
# 1   NaN   NaN   NaN   NaN   NaN  ...  2.60420  3.45446  3.69522  3.25580
# 2   NaN   NaN   NaN   NaN   NaN  ...      NaN      NaN      NaN      NaN
# ...

# %%
df = df.drop(['Country Code', 'Indicator Name', 'Indicator Code', 'Unnamed: 65'], axis=1)
df.head()
# Out:
#   Country Name  1960  1961  1962  1963  1964  1965  1966  1967  1968  ...  \
# 0        Aruba   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 1  Afghanistan   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 2       Angola   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 3      Albania   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 4      Andorra   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
#
#       2011     2012     2013     2014     2015     2016     2017     2018  \
# 0  6.11913  6.54906  6.50538  5.90521  5.97571  5.52415      NaN      NaN
# 1  3.46201  2.60420  3.45446  3.69522  3.25580  4.22836  4.05887      NaN
# 2      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 3      NaN      NaN  3.53930      NaN  3.43797  3.96209  3.61172      NaN
# 4  2.98706      NaN  2.50616  3.07421  3.28035  3.23707  3.21709  3.24672
#
#       2019  2020
# 0      NaN   NaN
# 1      NaN   NaN
# 2      NaN   NaN
# ...

# %%
colleges = pd.read_csv('finisheddataset.csv')

countries = colleges['Country'].unique()

count = colleges['Country'].value_counts().nlargest(30).index

count
# Out:
# Index(['United States', 'Japan', 'United Kingdom', 'China', 'India', 'Brazil',
#        'Spain', 'Italy', 'Germany', 'Russian Federation', 'Iran', 'Turkey',
#        'France', 'Taiwan', 'Australia', 'South Korea', 'Canada', 'Egypt',
#        'Chile', 'Poland', 'Czech Republic', 'Thailand', 'Mexico', 'Pakistan',
#        'Malaysia', 'Netherlands', 'Romania', 'Portugal', 'Sweden',
#        'South Africa'],
#       dtype='object')

# %%
for country in count:
    if country in df['Country Name'].values:
        print("yes", sep = " ")
    else:
        print(country)
# Out:
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# Iran
# yes
# yes
# Taiwan
# yes
# South Korea
# yes
# Egypt
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes

# %%
df[df['Country Name'] == 'Russian Federation']
# Out:
#            Country Name  1960  1961  1962  1963  1964  1965  1966  1967  1968  \
# 200  Russian Federation   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#      ...  2011    2012     2013     2014     2015     2016     2017  2018  \
# 200  ...   NaN  3.7931  3.76383  4.01388  3.83403  3.76044  4.68991   NaN
#
#      2019  2020
# 200   NaN   NaN
#
# [1 rows x 62 columns]

# %%
newdf = pd.DataFrame(columns = df.columns)

for country in count:
    newdf = newdf.append(df[df['Country Name']==country])
    
newdf
# Out:
#            Country Name  1960  1961  1962  1963  1964  1965  1966  1967  1968  \
# 249       United States   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 117               Japan   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 79       United Kingdom   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 38                China   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 107               India   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 27               Brazil   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 68                Spain   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 114               Italy   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 53              Germany   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 200  Russian Federation   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 242              Turkey   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# ...

# %%
newdf.to_csv('Investmentoneducation.csv', index=False)
